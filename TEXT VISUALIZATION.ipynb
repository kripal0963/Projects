# %%
# !pip install Wordcloud
# Out:
# Requirement already satisfied: Wordcloud in c:\users\kripal\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\kripal\anaconda3\lib\site-packages (from Wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\kripal\anaconda3\lib\site-packages (from Wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\kripal\anaconda3\lib\site-packages (from Wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kripal\anaconda3\lib\site-packages (from matplotlib->Wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kripal\anaconda3\lib\site-packages (from matplotlib->Wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kripal\anaconda3\lib\site-packages (from matplotlib->Wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kripal\anaconda3\lib\site-packages (from matplotlib->Wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kripal\anaconda3\lib\site-packages (from matplotlib->Wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kripal\anaconda3\lib\site-packages (from matplotlib->Wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kripal\anaconda3\lib\site-packages (from matplotlib->Wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kripal\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->Wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt

# %%
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")

# %%
text
# Out:
# 'Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble'

# %%
wordcloud = WordCloud(width=420, height=200, margin=2, background_color='black', 
                      colormap='Accent', mode='RGBA').generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
